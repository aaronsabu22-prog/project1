# %%
# !pip install langchain
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install pypdf
# !pip install transformers
# !pip install torch

# %% [markdown]
# # PROJECT- AI Research Paper Assistant

# %%
# !pip install -U langchain-community pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(r"C:\Users\STRAN\Desktop\NEST INTERNSHIP\ml basics\ml model- project\researchpaper.pdf")

documents = loader.load()

print("Number of pages:", len(documents))
# Out:
# C:\Users\STRAN\AppData\Local\Temp\ipykernel_10860\2856745963.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Number of pages: 1

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

docs = text_splitter.split_documents(documents)

print("Number of chunks:", len(docs))
print(docs[0].page_content)
# Out:
# Number of chunks: 1
# Title
# AI-Powered Research Paper Analysis using Retrieval-Augmented Generation (RAG)
# Abstract
# This paper presents a Research Paper Assistant that extracts text from PDF files, creates
# embeddings, stores them in a FAISS vector database, and uses a language model to answer
# questions based on retrieved context.
# Introduction
# Reading research papers is time-consuming. Retrieval-Augmented Generation combines semantic
# search with large language models to improve document understanding.
# Methodology
# The pipeline includes PDF upload, text extraction, chunking, embedding generation using
# sentence-transformers, FAISS indexing, similarity search, and response generation with FLAN-T5.
# Results
# The system supports question answering, summarization, quiz generation, and comparison of
# research topics with accurate retrieval.
# Conclusion
# The proposed assistant reduces reading effort and improves knowledge discovery for researchers
# and students.

# %%
# !pip install chromadb sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.6/23.5 MB 9.4 MB/s eta 0:00:03
#    ------ --------------------------------- 3.7/23.5 MB 9.8 MB/s eta 0:00:03
#    -------- ------------------------------- 5.0/23.5 MB 8.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 6.3/23.5 MB 8.1 MB/s eta 0:00:03
#    ------------ --------------------------- 7.6/23.5 MB 7.7 MB/s eta 0:00:03
#    --------------- ------------------------ 9.2/23.5 MB 7.6 MB/s eta 0:00:02
#    ------------------ --------------------- 10.7/23.5 MB 7.7 MB/s eta 0:00:02
#    -------------------- ------------------- 12.1/23.5 MB 7.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 13.9/23.5 MB 7.7 MB/s eta 0:00:02
#    --------------------------- ------------ 16.0/23.5 MB 7.9 MB/s eta 0:00:01
#    ------------------------------ --------- 18.1/23.5 MB 8.1 MB/s eta 0:00:01
# ...

# %%
# !pip install -U langchain langchain-community langchain-huggingface langchain-chroma
# Out:
# ...
#
#    ---------------------------------------- 2/2 [langchain-chroma]
#
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# ...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embedding_model,
    persist_directory="research_db"
)

print("Embeddings created successfully!")
# Out:
# Embeddings created successfully!

# %%
retriever = vectorstore.as_retriever()

results = retriever.invoke("What is this paper about?")

print(results[0].page_content)
# Out:
# Title
# AI-Powered Research Paper Analysis using Retrieval-Augmented Generation (RAG)
# Abstract
# This paper presents a Research Paper Assistant that extracts text from PDF files, creates
# embeddings, stores them in a FAISS vector database, and uses a language model to answer
# questions based on retrieved context.
# Introduction
# Reading research papers is time-consuming. Retrieval-Augmented Generation combines semantic
# search with large language models to improve document understanding.
# Methodology
# The pipeline includes PDF upload, text extraction, chunking, embedding generation using
# sentence-transformers, FAISS indexing, similarity search, and response generation with FLAN-T5.
# Results
# The system supports question answering, summarization, quiz generation, and comparison of
# research topics with accurate retrieval.
# Conclusion
# The proposed assistant reduces reading effort and improves knowledge discovery for researchers
# and students.

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedding,
    persist_directory="./research_db"
)
# Out:
# C:\Users\STRAN\AppData\Local\Temp\ipykernel_10860\4209736296.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding = HuggingFaceEmbeddings(
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
vectordb.persist()
# Out:
# C:\Users\STRAN\AppData\Local\Temp\ipykernel_10860\3711397106.py:1: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectordb.persist()

# %%
import os

print(os.path.exists("research_db"))
print(os.listdir("research_db"))
# Out:
# True
# ['0f7cf77e-ccc4-4d30-85b3-9939bb2c2d8e', 'chroma.sqlite3']

# %%
pip install fastapi uvicorn langchain langchain-community sentence-transformers faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\STRAN\Desktop\NEST INTERNSHIP\ml basics\ml model- project
# ['.ipynb_checkpoints', 'project.ipynb', 'researchpaper.pdf', 'research_db']

# %%
import os

print(os.listdir("research_db"))
# Out:
# ['0f7cf77e-ccc4-4d30-85b3-9939bb2c2d8e', 'chroma.sqlite3']

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectordb = Chroma(
    persist_directory="research_db",
    embedding_function=embedding_model
)

print("Database loaded successfully")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Database loaded successfully
